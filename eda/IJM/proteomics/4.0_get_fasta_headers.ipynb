# %% [markdown]
# ### Get fasta headers for use in drop down menu

# %%
from sqlalchemy import create_engine, MetaData, Table, select, join
import pandas as pd
import re

# SQLite path
db_path = 'sqlite:///../../../data/SQLite Database/20200527/Covid-19 Study DB.sqlite'

omics_id_dict = {
        "proteomics":1,
        "lipidomics":2,
        "metabolomics":3,
        "transcriptomics":4
    }

def get_biomolecule_names(dataset='proteomics'):

    omics_id = omics_id_dict[dataset]

    # Create an engine that connects to the Covid-19 Study DB.sqlite file: engine
    engine = create_engine(db_path)

    # Establish connection
    connection = engine.connect()

    query = "SELECT * from biomolecules WHERE omics_id={} and KEEP=1".format(omics_id)
    # get biomolecule names
    biomolecules_df = pd.read_sql_query(query, connection)

    # build biomolecule name dict and drop list
    biomolecule_name_dict = {}
    for index, row in biomolecules_df.iterrows():
        biomolecule_id = str(row['biomolecule_id'])
        standardized_name = row['standardized_name']
        biomolecule_name_dict[biomolecule_id] = standardized_name

    # return dictionary with biomolecule ids and standard names

    if not dataset=="proteomics":

        # close DB connection
        connection.close()



        return biomolecule_name_dict

    # for proteomics data, return fasta headers instead

    query = "SELECT * from metadata"
    # get biomolecule names
    metadata_df = pd.read_sql_query(query, connection)

    ## NOTE: Could swap this with fasta headers once they're available
    gene_name_df = metadata_df[metadata_df['metadata_type'] == 'gene_name']
    gene_name_df = gene_name_df.astype({'biomolecule_id': 'str'})
    
    fasta_header_df = metadata_df[metadata_df['metadata_type'] == 'fasta_header']
    fasta_header_df = fasta_header_df.astype({'biomolecule_id': 'str'})

    for biomolecule_id in biomolecule_name_dict:
        # update to gene name
        #gene_name = gene_name_df[gene_name_df['biomolecule_id']==biomolecule_id]['metadata_value'].values[0]
        fasta_header = fasta_header_df[fasta_header_df['biomolecule_id']==biomolecule_id]['metadata_value'].values[0]
        fasta_header = re.search("\s(.*?)\sO[SX]=", fasta_header).group(1)
        biomolecule_name_dict[biomolecule_id] = fasta_header
        

    # close DB connection
    connection.close()

    return biomolecule_name_dict, fasta_header_df

# %%
biomolecule_name_dict, fasta_header_df = get_biomolecule_names()

# %%
biomolecule_name_dict
# Out:
# {'7593': 'Alpha-1-antitrypsin',
#  '7596': 'Immunoglobulin lambda variable 4-69',
#  '7597': 'Immunoglobulin lambda variable 8-61',
#  '7599': 'Immunoglobulin lambda variable 10-54',
#  '7600': 'Immunoglobulin lambda variable 7-46',
#  '7601': 'Immunoglobulin lambda variable 5-37',
#  '7602': 'Immunoglobulin lambda variable 2-18',
#  '7605': 'Immunoglobulin lambda variable 3-10',
#  '7606': 'Immunoglobulin lambda variable 3-9',
#  '7607': 'Immunoglobulin kappa variable 2-28',
#  '7608': 'Immunoglobulin heavy variable 3-64',
#  '7610': 'Immunoglobulin kappa variable 2D-29',
#  '7611': 'Immunoglobulin kappa variable 1-27',
#  '7612': 'Immunoglobulin kappa variable 1-37 (non-functional) (Fragment)',
#  '7613': 'Immunoglobulin heavy variable 3/OR16-12 (non-functional) (Fragment)',
#  '7614': 'Immunoglobulin heavy variable 1/OR15-1 (non-functional) (Fragment)',
#  '7617': 'Immunoglobulin heavy variable 4-30-2',
#  '7618': 'Carboxypeptidase B2',
#  '7619': 'Immunoglobulin kappa variable 3D-15',
#  '7622': 'Proteasome subunit beta type-3 (Fragment)',
#  '7627': 'UTP--glucose-1-phosphate uridylyltransferase',
#  '7628': 'Beta-parvin',
#  '7629': 'Hypoxia up-regulated protein 1',
#  '7630': 'Neural cell adhesion molecule L1-like protein',
#  '7631': 'Immunoglobulin kappa variable 2-40',
#  '7632': 'Collagen alpha-1(VI) chain',
#  '7634': 'Glutathione peroxidase',
#  '7635': 'SAA2-SAA4 readthrough',
#  '7636': 'Coagulation factor V',
#  '7638': 'Immunoglobulin heavy constant delta (Fragment)',
#  '7639': 'Immunoglobulin heavy variable 1-45',
#  '7640': 'Immunoglobulin heavy variable 3-49',
#  '7641': 'Poliovirus receptor',
#  '7642': 'Peroxiredoxin-1 (Fragment)',
#  '7643': 'Immunoglobulin kappa variable 6D-21',
#  '7644': 'Integrin-linked protein kinase',
#  '7647': 'Immunoglobulin lambda variable 1-36',
#  '7648': 'Immunoglobulin heavy variable 6-1',
#  '7649': 'Immunoglobulin heavy variable 3-15',
#  '7650': 'Immunoglobulin heavy variable 3-21',
#  '7651': 'Immunoglobulin heavy variable 2-26',
#  '7652': 'Immunoglobulin heavy variable 3-73',
#  '7653': 'Immunoglobulin heavy variable 7-81 (non-functional) (Fragment)',
#  '7654': 'Immunoglobulin heavy variable 3-74',
#  '7655': 'Immunoglobulin heavy variable 3-43',
#  '7656': 'Immunoglobulin lambda variable 9-49',
#  '7657': 'Immunoglobulin heavy variable 3-72',
#  '7658': 'Immunoglobulin lambda-like polypeptide 5',
#  '7661': 'Immunoglobulin heavy variable 1-69D',
#  '7662': 'Cartilage acidic protein 1',
#  '7664': 'Glycoprotein Ib (Platelet), alpha polypeptide',
#  '7665': 'Immunoglobulin kappa variable 6-21',
#  '7666': 'Immunoglobulin kappa variable 3D-20',
#  '7667': 'Immunoglobulin heavy variable 1-3',
#  '7669': 'Immunoglobulin heavy variable 1-18',
#  '7670': 'Immunoglobulin heavy variable 3-20',
#  '7671': 'Immunoglobulin heavy variable 1-24',
#  '7672': 'Immunoglobulin heavy variable 4-28',
#  '7674': 'Immunoglobulin heavy variable 3-38 (non-functional) (Fragment)',
#  '7675': 'Immunoglobulin heavy variable 5-51',
#  '7677': 'Immunoglobulin heavy variable 4-61',
#  '7678': 'Immunoglobulin heavy variable 2-70D',
#  '7679': 'Immunoglobulin kappa variable 1-8',
#  '7680': 'Immunoglobulin kappa variable 2-24',
#  '7682': 'Immunoglobulin kappa variable 1-12',
#  '7684': 'Complement factor H',
#  '7685': 'Heat shock 70 kDa protein 1B',
#  '7686': 'Immunoglobulin heavy constant alpha 2 (Fragment)',
#  '7688': 'Complement C4-A',
#  '7689': 'Immunoglobulin kappa variable 1D-8 (Fragment)',
#  '7690': 'Uncharacterized protein (Fragment)',
#  '7691': 'Immunoglobulin lambda variable 5-45 (Fragment)',
#  '7693': 'Immunoglobulin heavy variable 3-64D',
#  '7694': 'LIM and senescent cell antigen-like-containing domain protein',
#  '7695': 'Immunoglobulin heavy variable 5-10-1',
#  '7696': 'Uncharacterized protein (Fragment)',
#  '7697': 'Cathepsin D',
#  '7700': 'Immunoglobulin heavy constant gamma 4 (Fragment)',
#  '7701': 'Immunoglobulin kappa variable 1-33',
#  '7703': 'Complement factor H-related protein 2',
#  '7705': 'Vitamin K-dependent protein S',
#  '7706': 'Complement C1r subcomponent',
#  '7707': 'Tenascin-X',
#  '7708': 'Immunoglobulin lambda constant 7',
#  '7711': 'Immunoglobulin kappa variable 2-29',
#  '7715': 'Putative annexin A2-like protein',
#  '7716': 'Protease serine 2 preproprotein',
#  '7717': 'Insulin-like growth factor binding protein 3 isoform b',
#  '7720': 'Apolipoprotein C-III',
#  '7721': 'Periostin',
#  '7723': 'Actin-related protein 3',
#  '7724': 'cDNA FLJ55673, highly similar to Complement factor B',
#  '7726': 'D-dopachrome decarboxylase',
#  '7727': 'ITIH4 protein',
#  '7730': 'Serotransferrin (Fragment)',
#  '7731': 'Latent-transforming growth factor beta-binding protein 1',
#  '7733': 'Apolipoprotein D (Fragment)',
#  '7735': 'Long-chain-fatty-acid--CoA ligase 6 (Fragment)',
#  '7737': 'Complement C1q subcomponent subunit B',
#  '7744': 'Pulmonary surfactant-associated protein B',
#  '7746': 'Vitamin K-dependent protein C',
#  '7747': 'Collagen alpha-3(VI) chain',
#  '7749': 'Lactotransferrin',
#  '7750': 'Thrombospondin-4',
#  '7751': 'Uncharacterized protein',
#  '7752': 'Ectonucleotide pyrophosphatase/phosphodiesterase family member 2',
#  '7753': 'Neuropilin-1',
#  '7755': 'Macrophage colony-stimulating factor 1 receptor',
#  '7756': 'Versican core protein',
#  '7758': 'Tetranectin',
#  '7759': 'Uncharacterized protein',
#  '7761': 'Scavenger receptor cysteine-rich type 1 protein M130',
#  '7763': 'Coagulation factor VII',
#  '7765': 'Plexin-C1 (Fragment)',
#  '7766': 'Heterogeneous nuclear ribonucleoprotein A1 (Fragment)',
#  '7767': 'Nucleosome assembly protein 1-like 1',
#  '7768': 'Myosin light polypeptide 6',
#  '7769': 'Unconventional myosin-Va',
#  '7771': 'Protein Z-dependent protease inhibitor',
#  '7772': 'Alpha-1-antichymotrypsin',
#  '7773': 'Proteasome subunit alpha type',
#  '7775': 'Fibulin-5',
#  '7776': 'Hepatocyte growth factor-like protein',
#  '7777': 'Complement factor I',
#  '7778': 'Cartilage oligomeric matrix protein',
#  '7779': 'Haptoglobin',
#  '7780': 'Low affinity immunoglobulin gamma Fc region receptor III-A (Fragment)',
#  '7781': 'Plasma kallikrein (Fragment)',
#  '7785': 'Poly(rC)-binding protein 2 (Fragment)',
#  '7786': 'Collagen alpha-1(XVIII) chain (Fragment)',
#  '7791': 'Cathelicidin antimicrobial peptide',
#  '7792': 'Cysteine-rich secretory protein 3',
#  '7794': 'Intercellular adhesion molecule 2 (Fragment)',
#  '7795': 'Myosin regulatory light chain 12A',
#  '7799': 'APOC4-APOC2 readthrough (NMD candidate)',
#  '7800': 'Complement factor D',
#  '7803': 'Complement C3 (Fragment)',
#  '7804': 'PDZ and LIM domain protein 1',
#  '7805': 'Mannan-binding lectin serine protease 2',
#  '7806': 'Ras-related protein Rab-27B',
#  '7807': 'Chloride intracellular channel protein 1',
#  '7808': 'Sulfhydryl oxidase 1',
#  '7809': 'Apolipoprotein L1',
#  '7814': 'HLA class I antigen',
#  '7816': 'CD5 antigen-like',
#  '7818': 'WD repeat-containing protein 1',
#  '7820': 'Serine/threonine-protein kinase/endoribonuclease IRE1',
#  '7821': 'Ficolin-3',
#  '7823': 'Isocitrate dehydrogenase [NADP] cytoplasmic',
#  '7824': 'Isoform 2 of Attractin',
#  '7826': 'Apolipoprotein M',
#  '7827': 'Pantetheinase',
#  '7828': 'Caveolae-associated protein 2',
#  '7829': 'Isoform 4 of Apoptosis-inducing factor 1, mitochondrial',
#  '7835': 'Isoform 4 of Glutathione reductase, mitochondrial',
#  '7836': 'Superoxide dismutase [Cu-Zn]',
#  '7837': 'Ceruloplasmin',
#  '7838': 'Coagulation factor XIII A chain',
#  '7839': 'Purine nucleoside phosphorylase',
#  '7841': 'Phosphoglycerate kinase 1',
#  '7843': 'Prothrombin',
#  '7844': 'Haptoglobin',
#  '7845': 'Haptoglobin-related protein',
#  '7846': 'Coagulation factor IX',
#  '7847': 'Coagulation factor X',
#  '7848': 'Plasminogen',
#  '7849': 'Coagulation factor XII',
#  '7850': 'Carbonic anhydrase 1',
#  '7851': 'Carbonic anhydrase 2',
#  '7852': 'Argininosuccinate synthase',
#  '7853': 'Antithrombin-III',
#  '7854': 'Alpha-1-antitrypsin',
#  '7855': 'Alpha-1-antichymotrypsin',
#  '7856': 'Angiotensinogen',
#  '7857': 'Alpha-2-macroglobulin',
#  '7858': 'Complement C3',
#  '7859': 'Complement C5',
#  '7860': 'Cystatin-C',
#  '7861': 'Kininogen-1',
#  '7862': 'Isoform LMW of Kininogen-1',
#  '7863': 'Isoform 3 of Insulin-like growth factor II',
#  '7864': 'Immunoglobulin J chain',
#  '7865': 'Immunoglobulin kappa variable 1-17',
#  '7866': 'Immunoglobulin kappa variable 1D-16',
#  '7867': 'Immunoglobulin kappa variable 1-5',
#  '7868': 'Immunoglobulin kappa variable 3-20',
#  '7869': 'Immunoglobulin kappa variable 3-15',
#  '7870': 'Immunoglobulin lambda variable 1-44',
#  '7871': 'Immunoglobulin lambda variable 1-47',
#  '7872': 'Immunoglobulin lambda variable 1-51',
#  '7873': 'Immunoglobulin lambda variable 1-40',
#  '7874': 'Immunoglobulin lambda variable 2-11',
#  '7875': 'Immunoglobulin lambda variable 3-19',
#  '7876': 'Immunoglobulin lambda variable 3-1',
#  '7877': 'Immunoglobulin lambda variable 3-25',
#  '7878': 'Immunoglobulin lambda variable 3-27',
#  '7879': 'Immunoglobulin lambda variable 6-57',
#  '7880': 'Immunoglobulin heavy variable 1-69',
#  '7881': 'Immunoglobulin heavy variable 1-46',
#  '7882': 'Immunoglobulin heavy variable 3-11',
#  '7884': 'Immunoglobulin heavy variable 3-23',
#  '7885': 'Immunoglobulin heavy variable 3-13',
#  '7886': 'Immunoglobulin heavy variable 3-53',
#  '7887': 'Immunoglobulin heavy variable 3-33',
#  '7888': 'Immunoglobulin heavy variable 3-7',
#  '7890': 'Immunoglobulin heavy variable 2-70',
#  '7891': 'Immunoglobulin heavy variable 2-5',
#  '7893': 'Polymeric immunoglobulin receptor',
#  '7894': 'Immunoglobulin kappa constant',
#  '7896': 'Immunoglobulin heavy constant gamma 1',
#  '7897': 'Immunoglobulin heavy constant gamma 2',
#  '7898': 'Immunoglobulin heavy constant gamma 3',
#  '7899': 'Immunoglobulin heavy constant mu',
#  '7900': 'Immunoglobulin heavy constant alpha 1',
#  '7901': 'Immunoglobulin heavy constant alpha 2',
#  '7903': 'Myoglobin',
#  '7904': 'Isoform 2 of Spectrin alpha chain, erythrocytic 1',
#  '7905': 'Apolipoprotein A-I',
#  '7906': 'Apolipoprotein E',
#  '7907': 'Fibrinogen alpha chain',
#  '7908': 'Fibrinogen beta chain',
#  '7909': 'Fibrinogen gamma chain',
#  '7910': 'Band 3 anion transport protein',
#  '7912': 'Serum amyloid P-component',
#  '7913': 'Complement C1q subcomponent subunit A',
#  '7914': 'Complement C1q subcomponent subunit C',
#  '7915': 'Complement component C9',
#  '7916': 'Beta-2-glycoprotein 1',
#  '7917': 'Leucine-rich alpha-2-glycoprotein',
#  '7918': 'Fibronectin',
#  '7919': 'Protein AMBP',
#  '7920': 'Alpha-1-acid glycoprotein 1',
#  '7921': 'Alpha-2-HS-glycoprotein',
#  '7922': 'Transthyretin',
#  '7923': 'Serum albumin',
#  '7924': 'Vitamin D-binding protein',
#  '7925': 'Platelet basic protein',
#  '7927': 'Transferrin receptor protein 1',
#  '7928': 'Serotransferrin',
#  '7929': 'Hemopexin',
#  '7930': 'Ferritin light chain',
#  '7932': 'Angiogenin',
#  '7933': 'Coagulation factor XI',
#  '7934': 'C4b-binding protein alpha chain',
#  '7935': 'Vitronectin',
#  '7936': 'Catalase',
#  '7937': 'Fructose-bisphosphate aldolase A',
#  '7938': 'Apolipoprotein B-100',
#  '7939': 'Superoxide dismutase [Mn], mitochondrial',
#  '7940': 'Phosphatidylcholine-sterol acyltransferase',
#  '7941': 'Histidine-rich glycoprotein',
#  '7942': 'Immunoglobulin lambda variable 7-43',
#  '7943': 'Alpha-1B-glycoprotein',
#  '7944': 'von Willebrand factor',
#  '7945': 'Sex hormone-binding globulin',
#  '7948': 'Immunoglobulin kappa variable 1-16',
#  '7949': 'Immunoglobulin kappa variable 1D-39',
#  '7950': 'Immunoglobulin kappa variable 3-11',
#  '7952': 'Heat shock protein beta-1',
#  '7953': 'Fructose-bisphosphate aldolase B',
#  '7954': 'Integrin beta-3',
#  '7955': 'Protein S100-A8',
#  '7956': 'Isoform 2 of Plasminogen activator inhibitor 1',
#  '7957': 'Plasma serine protease inhibitor',
#  '7958': 'Plasma protease C1 inhibitor',
#  '7959': 'Coagulation factor XIII B chain',
#  '7961': 'Intercellular adhesion molecule 1',
#  '7966': 'HLA class I histocompatibility antigen, A-24 alpha chain',
#  '7967': 'Thyroxine-binding globulin',
#  '7968': 'Heparin cofactor 2',
#  '7969': 'Isoform MLC3 of Myosin light chain 1/3, skeletal muscle isoform',
#  '7970': 'Cholinesterase',
#  '7971': 'Immunoglobulin kappa variable 2-30',
#  '7972': 'Immunoglobulin kappa variable 4-1',
#  '7973': 'Immunoglobulin heavy variable 4-34',
#  '7974': 'Gelsolin',
#  '7975': 'ATP synthase subunit beta, mitochondrial',
#  '7976': 'Complement C2',
#  '7977': 'Protein S100-A9',
#  '7978': 'Apolipoprotein A-IV',
#  '7979': 'Creatine kinase M-type',
#  '7980': 'Alpha-enolase',
#  '7981': 'Glycogen phosphorylase, liver form',
#  '7982': 'Glucose-6-phosphate isomerase',
#  '7984': 'L-lactate dehydrogenase B chain',
#  '7985': 'Protein disulfide-isomerase',
#  '7987': 'Complement component C8 alpha chain',
#  '7988': 'Complement component C8 beta chain',
#  '7989': 'Complement component C8 gamma chain',
#  '7990': 'Calpain-1 catalytic subunit',
#  '7992': 'Profilin-1',
#  '7994': 'Heat shock protein HSP 90-alpha',
#  '7997': 'Ribonuclease pancreatic',
#  '7998': 'Corticosteroid-binding globulin',
#  '8000': 'Heat shock protein HSP 90-beta',
#  '8001': 'Neutrophil elastase',
#  '8002': 'Extracellular superoxide dismutase [Cu-Zn]',
#  '8003': 'Matrix Gla protein',
#  '8004': 'Isoform 3 of Integrin alpha-IIb',
#  '8005': 'Apolipoprotein(a)',
#  '8006': 'Pleckstrin',
#  '8007': 'Monocyte differentiation antigen CD14',
#  '8008': 'Complement factor H',
#  '8009': 'Alpha-2-antiplasmin',
#  '8011': 'Dopamine beta-hydroxylase',
#  '8014': 'SPARC',
#  '8016': 'Isoform 4 of Tropomyosin alpha-1 chain',
#  '8017': 'Complement C1s subcomponent',
#  '8018': 'Isoform 2 of Leukotriene A-4 hydrolase',
#  '8019': 'Complement C4-A',
#  '8020': 'Complement C4-B',
#  '8021': 'Polyubiquitin-C',
#  '8022': 'Serum amyloid A-1 protein',
#  '8023': 'Serum amyloid A-2 protein',
#  '8025': 'Immunoglobulin lambda constant 2',
#  '8026': 'Immunoglobulin heavy variable 1-8',
#  '8027': 'Immunoglobulin heavy variable 3-30-3',
#  '8028': 'Immunoglobulin heavy variable 3-30-5',
#  '8030': 'Immunoglobulin heavy variable 4-38-2',
#  '8031': 'Immunoglobulin kappa variable 1-13',
#  '8032': 'Calmodulin-3',
#  '8033': 'Serglycin',
#  '8035': 'Thioredoxin',
#  '8036': 'Complement component C7',
#  '8037': 'Chromogranin-A',
#  '8038': '60 kDa heat shock protein, mitochondrial',
#  '8039': 'Isoform 4 of Clusterin',
#  '8040': 'Endoplasmic reticulum chaperone BiP',
#  '8041': 'Heat shock cognate 71 kDa protein',
#  '8043': 'Solute carrier family 2, facilitated glucose transporter member 3',
#  '8045': 'Mannose-binding protein C',
#  '8049': 'Cholesteryl ester transfer protein',
#  '8050': 'ADP/ATP translocase 3',
#  '8052': 'Alpha-actinin-1',
#  '8053': 'Xaa-Pro dipeptidase',
#  '8054': 'Isoform LAMP-2B of Lysosome-associated membrane glycoprotein 2',
#  '8055': 'Isoform 4 of Neural cell adhesion molecule 1',
#  '8056': 'Elongation factor 2',
#  '8057': 'Complement component C6',
#  '8059': 'Plastin-2',
#  '8061': 'L-selectin',
#  '8062': 'Nidogen-1',
#  '8066': 'Platelet glycoprotein IX',
#  '8070': 'Aminopeptidase N',
#  '8071': 'Carboxypeptidase N catalytic chain',
#  '8072': 'Isoform Short of Beta-1,4-galactosyltransferase 1',
#  '8073': 'Immunoglobulin lambda-like polypeptide 1',
#  '8074': 'CD44 antigen',
#  '8076': 'Isoform Er13 of Ankyrin-1',
#  '8078': 'Fumarylacetoacetase',
#  '8079': 'Heat shock 70 kDa protein 6',
#  '8082': 'Insulin-like growth factor-binding protein 2',
#  '8083': 'Isoform 1 of Vinculin',
#  '8084': 'Lipopolysaccharide-binding protein',
#  '8085': 'Phosphoglycerate mutase 1',
#  '8088': 'Alpha-1-acid glycoprotein 2',
#  '8089': 'Inter-alpha-trypsin inhibitor heavy chain H1',
#  '8090': 'Pregnancy zone protein',
#  '8091': 'C4b-binding protein beta chain',
#  '8094': 'Isoform 2 of Insulin-like growth factor-binding protein 4',
#  '8095': 'Carboxypeptidase N subunit 2',
#  '8096': 'Vitamin K-dependent protein Z',
#  '8097': 'Macrophage mannose receptor 1',
#  '8098': 'Immunoglobulin heavy variable 1-2',
#  '8100': 'Fibulin-1',
#  '8101': 'Isoform C of Fibulin-1',
#  '8102': 'Peptidyl-prolyl cis-trans isomerase B',
#  '8103': 'Tryptophan--tRNA ligase, cytoplasmic',
#  '8105': 'Cofilin-1',
#  '8106': 'Insulin-like growth factor-binding protein 6',
#  '8107': 'Isoform 4 of Tenascin',
#  '8108': 'Zinc-alpha-2-glycoprotein',
#  '8110': 'ATP synthase subunit alpha, mitochondrial',
#  '8111': 'Proteasome subunit alpha type-1',
#  '8114': 'Moesin',
#  '8115': 'Erythrocyte band 7 integral membrane protein',
#  '8116': 'Serum paraoxonase/arylesterase 1',
#  '8117': 'Calreticulin',
#  '8118': 'Properdin',
#  '8119': 'Proteasome subunit alpha type-5',
#  '8120': 'Proteasome subunit beta type-4',
#  '8122': 'Cytosol aminopeptidase',
#  '8123': 'Transketolase',
#  '8124': 'Kallistatin',
#  '8125': 'Peroxiredoxin-6',
#  '8126': 'Flavin reductase (NADPH)',
#  '8127': 'Phosphatidylethanolamine-binding protein 1',
#  '8128': 'Protein disulfide-isomerase A3',
#  '8129': 'HLA class I histocompatibility antigen, A-34 alpha chain',
#  '8130': 'HLA class I histocompatibility antigen, B-53 alpha chain',
#  '8133': 'Leukocyte elastase inhibitor',
#  '8134': 'Coronin-1A',
#  '8136': 'Isoform Short of 14-3-3 protein beta/alpha',
#  '8137': 'Peroxiredoxin-2',
#  '8138': 'Cadherin-5',
#  '8140': 'Ribonuclease 4',
#  '8142': 'Insulin-like growth factor-binding protein complex acid labile subunit',
#  '8143': 'Chitinase-3-like protein 1',
#  '8145': 'Pigment epithelium-derived factor',
#  '8146': 'Transgelin-2',
#  '8147': 'Transaldolase',
#  '8148': 'Platelet glycoprotein V',
#  '8149': 'T-complex protein 1 subunit zeta',
#  '8150': 'Malate dehydrogenase, cytoplasmic',
#  '8151': 'Malate dehydrogenase, mitochondrial',
#  '8152': 'Prostaglandin-H2 D-isomerase',
#  '8154': 'Cell surface glycoprotein MUC18',
#  '8155': 'Isoform 4 of Biotinidase',
#  '8156': 'Afamin',
#  '8157': 'Mannan-binding lectin serine protease 1',
#  '8158': 'Isoform 2 of Mannan-binding lectin serine protease 1',
#  '8160': 'Selenoprotein P',
#  '8161': 'Rab GDP dissociation inhibitor beta',
#  '8163': 'Vasodilator-stimulated phosphoprotein',
#  '8164': 'Lumican',
#  '8168': 'Rho GDP-dissociation inhibitor 2',
#  '8170': 'F-actin-capping protein subunit alpha-1',
#  '8171': 'Apolipoprotein C-IV',
#  '8172': 'Phospholipid transfer protein',
#  '8174': 'Neutrophil defensin 3',
#  '8175': 'Isoform 2 of Triosephosphate isomerase',
#  '8176': 'Actin, cytoplasmic 1',
#  '8179': 'Ras-related protein Rap-1b',
#  '8180': 'Lysozyme C',
#  '8181': 'Beta-2-microglobulin',
#  '8182': '14-3-3 protein gamma',
#  '8184': '14-3-3 protein epsilon',
#  '8185': 'Histone H4',
#  '8187': 'Isoform B of Ras-related C3 botulinum toxin substrate 1',
#  '8188': '14-3-3 protein zeta/delta',
#  '8189': 'Eukaryotic translation initiation factor 5A-1',
#  '8190': 'Actin, cytoplasmic 2',
#  '8191': 'Tropomyosin alpha-4 chain',
#  '8192': 'Actin, alpha cardiac muscle 1',
#  '8193': 'Elongation factor 1-alpha 1',
#  '8194': 'Tubulin alpha-1B chain',
#  '8195': 'Isoform 2 of Tubulin alpha-4A chain',
#  '8196': 'Tubulin beta-4B chain',
#  '8197': 'Histone H3.1',
#  '8198': 'Hemoglobin subunit beta',
#  '8200': 'Hemoglobin subunit alpha',
#  '8202': 'Phosphatidylinositol-glycan-specific phospholipase D',
#  '8204': 'Immunoglobulin lambda variable 3-21',
#  '8210': 'Adenylyl cyclase-associated protein 1',
#  '8211': 'Nucleobindin-1',
#  '8212': 'Complement factor H-related protein 3',
#  '8214': 'Complement factor H-related protein 1',
#  '8216': 'Hepatocyte growth factor activator',
#  '8218': 'Isoform 2 of Inter-alpha-trypsin inhibitor heavy chain H3',
#  '8219': 'Regenerating islet-derived protein 3-alpha',
#  '8221': 'Galectin-3-binding protein',
#  '8224': 'Isoform 2 of EGF-containing fibulin-like extracellular matrix protein 1',
#  '8226': 'Secreted phosphoprotein 24',
#  '8227': 'Multimerin-1',
#  '8229': 'Methanethiol oxidase',
#  '8231': 'Apolipoprotein F',
#  '8232': 'Dystroglycan',
#  '8234': 'SPARC-like protein 1',
#  '8235': 'Isoform 2 of Hyaluronan-binding protein 2',
#  '8236': 'Inter-alpha-trypsin inhibitor heavy chain H4',
#  '8237': 'Neutral alpha-glucosidase AB',
#  '8238': 'LIM and SH3 domain protein 1',
#  '8240': 'Isoform 3 of Protein disulfide-isomerase A6',
#  '8241': 'Procollagen C-endopeptidase enhancer 1',
#  '8242': 'Serum paraoxonase/lactonase 3',
#  '8244': 'Ras suppressor protein 1',
#  '8245': 'Ficolin-2',
#  '8246': 'Transforming growth factor-beta-induced protein ig-h3',
#  '8248': 'Adiponectin',
#  '8249': 'Zyxin',
#  '8250': 'Isoform 2 of Insulin-like growth factor-binding protein 7',
#  '8252': 'Extracellular matrix protein 1',
#  '8255': 'Nucleoside diphosphate kinase',
#  '8257': 'Metalloproteinase inhibitor 1',
#  '8258': 'Epididymis luminal protein 189',
#  '8260': 'Tubulin beta chain',
#  '8261': 'SH3 domain-binding glutamic acid-rich-like protein 3',
#  '8264': 'Inter-alpha-trypsin inhibitor heavy chain H2',
#  '8266': 'Tropomyosin beta chain',
#  '8268': 'Retinol-binding protein',
#  '8270': 'Vasorin',
#  '8271': 'Apolipoprotein A-V',
#  '8272': 'Plexin domain-containing protein 2',
#  '8273': 'Peptidase inhibitor 16',
#  '8274': 'Histone H3.2',
#  '8276': 'Histone H2A type 3',
#  '8278': 'Serpin A11',
#  '8280': 'Out at first protein homolog',
#  '8281': 'Isoform 2 of Fermitin family homolog 3',
#  '8282': 'Isoform 2 of Uncharacterized protein ZSWIM9',
#  '8283': 'Isoform 3 of Leukocyte immunoglobulin-like receptor subfamily A member 3',
#  '8288': 'Oncoprotein-induced transcript 3 protein',
#  '8290': 'Isoform 2 of Complement factor H-related protein 4',
#  '8291': 'Gamma-glutamyl hydrolase',
#  '8292': 'Isoform C of Proteoglycan 4',
#  '8296': 'Beta-Ala-His dipeptidase',
#  '8298': 'N-acetylmuramoyl-L-alanine amidase',
#  '8300': 'Protein/nucleic acid deglycase DJ-1',
#  '8302': 'Isoform 5 of Noelin',
#  '8303': 'Isoform 4 of T-complex protein 1 subunit eta',
#  '8304': 'Retinoic acid receptor responder protein 2',
#  '8306': 'Isoform 8 of Collectin-11',
#  '8307': 'Complement factor H-related protein 5',
#  '8309': 'Tubulin beta-1 chain',
#  '8311': 'Adipocyte plasma membrane-associated protein',
#  '8316': 'Complement C1r subcomponent-like protein',
#  '8318': 'Fetuin-B',
#  '8319': 'Prenylcysteine oxidase 1',
#  '8321': 'N-acetylglucosamine-1-phosphotransferase subunit gamma',
#  '8322': 'Coronin-1C',
#  '8323': 'Multiple inositol polyphosphate phosphatase 1',
#  '8328': 'Angiopoietin-related protein 3',
#  '8330': 'IgGFc-binding protein',
#  '8334': 'Histone H2B',
#  '8335': 'Low affinity immunoglobulin gamma Fc region receptor II-a (Fragment)',
#  '8336': 'Apolipoprotein A-II',
#  '8337': 'Neutrophil gelatinase-associated lipocalin'}

# %%
example_fasta_header = biomolecule_name_dict['7593']
print(example_fasta_header)
print()
fasta_header_regex = re.search("(.*?)\sO[SX]=", example_fasta_header).group(1)
print(fasta_header_regex)
# Out:
# Alpha-1-antitrypsin OS=Homo sapiens OX=9606 GN=SERPINA1 PE=1 SV=1;tr|A0A0G2JRN3|A0A0G2JRN3_HUMAN Alpha-1-antitrypsin OS=Homo sapiens
#
# Alpha-1-antitrypsin

# %%
fasta_header_df
# Out:
#        metadata_id biomolecule_id metadata_type  \
# 45444        45445           7593  fasta_header
# 45445        45446           7594  fasta_header
# 45446        45447           7595  fasta_header
# 45447        45448           7596  fasta_header
# 45448        45449           7597  fasta_header
# ...            ...            ...           ...
# 46184        46185           8333  fasta_header
# 46185        46186           8334  fasta_header
# 46186        46187           8335  fasta_header
# 46187        46188           8336  fasta_header
# 46188        46189           8337  fasta_header
#
#                                           metadata_value
# 45444  tr|A0A024R6I7|A0A024R6I7_HUMAN Alpha-1-antitry...
# 45445  tr|A0A024RA52|A0A024RA52_HUMAN Proteasome subu...
# 45446  tr|A0A075B6H7|A0A075B6H7_HUMAN Immunoglobulin ...
# 45447  sp|A0A075B6H9|LV469_HUMAN Immunoglobulin lambd...
# 45448  sp|A0A075B6I0|LV861_HUMAN Immunoglobulin lambd...
# ...                                                  ...
# 46184  tr|U3KPS2|U3KPS2_HUMAN Myeloblastin OS=Homo sa...
# 46185  tr|U3KQK0|U3KQK0_HUMAN Histone H2B OS=Homo sap...
# 46186  tr|V9GY83|V9GY83_HUMAN Low affinity immunoglob...
# 46187  tr|V9GYM3|V9GYM3_HUMAN Apolipoprotein A-II OS=...
# 46188  tr|X6R8F3|X6R8F3_HUMAN Neutrophil gelatinase-a...
#
# [745 rows x 4 columns]

# %%
biomolecule_id
# Out:
# '7593'

# %%
fasta_header_df[fasta_header_df['biomolecule_id']==biomolecule_id]
# Out:
#        metadata_id biomolecule_id metadata_type  \
# 46188        46189           8337  fasta_header
#
#                                           metadata_value
# 46188  tr|X6R8F3|X6R8F3_HUMAN Neutrophil gelatinase-a...
